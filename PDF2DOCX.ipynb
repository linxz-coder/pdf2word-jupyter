# %%
# !pip install pdf2docx
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pycparser-2.21-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pycparser-2.21-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/cffi-1.15.1-py3.11.egg-info due to invalid metadata entry 'name'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.4/148.4 kB 231.8 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 1.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 4.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 927.6 kB/s eta 0:00:00 0:00:01m
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=6e7bd00abfd6b762520968829c363019b514ffe1e3b6a5138eb7bfc0ff5e4df1
# ...

# %%
from pdf2docx import Converter
pdf_file = '/Users/lxz/小中的文件/电子书/Rework - Jason Fried.pdf'
docx_file = '/Users/lxz/小中的文件/电子书/rework.docx'
cv = Converter(pdf_file)
cv.convert(docx_file)
cv.close()
# Out:
# [INFO] Start to convert /Users/lxz/小中的文件/电子书/Rework - Jason Fried.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/129) Page 1
# [INFO] (2/129) Page 2
# [INFO] (3/129) Page 3
# [INFO] (4/129) Page 4
# [INFO] (5/129) Page 5
# [INFO] (6/129) Page 6
# [INFO] (7/129) Page 7
# [INFO] (8/129) Page 8
# [INFO] (9/129) Page 9
# [INFO] (10/129) Page 10
# [INFO] (11/129) Page 11
# [INFO] (12/129) Page 12
# [INFO] (13/129) Page 13
# [INFO] (14/129) Page 14
# [INFO] (15/129) Page 15
# [INFO] (16/129) Page 16
# [INFO] (17/129) Page 17
# [INFO] (18/129) Page 18
# [INFO] (19/129) Page 19
# [INFO] (20/129) Page 20
# [INFO] (21/129) Page 21
# [INFO] (22/129) Page 22
# [INFO] (23/129) Page 23
# [INFO] (24/129) Page 24
# [INFO] (25/129) Page 25
# [INFO] (26/129) Page 26
# [INFO] (27/129) Page 27
# [INFO] (28/129) Page 28
# [INFO] (29/129) Page 29
# [INFO] (30/129) Page 30
# [INFO] (31/129) Page 31
# [INFO] (32/129) Page 32
# ...
